# %%
import numpy as np
import matplotlib.image as pimg
import cv2
import os
from utils import *
import matplotlib.pyplot as plt

# %%
img_path='./sample image/rgb_image200.jpg'

# %%
img=pimg.imread(img_path)
plt.imshow(img)

# %%
gray_img=grayscale(img)
plt.imshow(img, cmap="gray")
plt.show()

# %%
gauss_img=gaussian_blur(gray_img,kernel_size=3)
cann=canny(gauss_img)
plt.imshow(cann, cmap='gray')

# %%
h,w=cann.shape
vectices=np.array([[0,h],[0,100],[w,100],[w,h]])
ROI=region_of_interest(cann,vectices)

# %%
plt.imshow(ROI, cmap='gray')

# %%
line_img,left_line,right_line = hough_lines(ROI)
plt.imshow(line_img, cmap='gray')

# %%
predict=weighted_img(line_img, img)
plt.imshow(predict)
plt.imsave('./test.jpg',predict)

# %%
print(left_line)
# Out:
# [(113, 100), (-51, 240)]

# %%
print(right_line)
# Out:
# [(113, 100), (-51, 240)]

# %%
img=pimg.imread('./test.jpg')

# %%
plt.imshow(img)
